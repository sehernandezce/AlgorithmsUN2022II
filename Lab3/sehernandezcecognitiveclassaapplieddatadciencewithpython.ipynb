# %% [markdown]
# <a href="https://colab.research.google.com/github/sehernandezce/AlgorithmsUN2022II/blob/main/Lab3/sehernandezcecognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LINKEDIN: https://www.linkedin.com/in/sebastiannzn/
#
# Python For Data Science: https://courses.cognitiveclass.ai/certificates/78dbd52969fe4902856fbfa271e379d0
#
# Data Analisis With Python: https://courses.cognitiveclass.ai/certificates/71172375e0aa45dcabaff951ab0fe2f1
#
# Data Visualization With Python: https://courses.cognitiveclass.ai/certificates/fdb9c1c172424847889436af491ebe79

# %% [markdown]
# ![sehernandezcecognitiveclassaapplieddatadciencewithpython.png](data:image/png;base64,...)
