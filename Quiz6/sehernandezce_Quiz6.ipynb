# %% [markdown]
# <a href="https://colab.research.google.com/github/sehernandezce/AlgorithmsUN2022II/blob/main/Quiz6/sehernandezce_Quiz6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In Quantiacs Q18 Quick Start test 3 values short and 3 values long. You must have a margin of 100 days before testing

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# **The short-term values are**: 6, 12, 24.
#
# **The long-term values are**: 101, 186, 240.
#
# **At 6 months:**
#
# data = qndata.stocks.load_ndx_data(min_date="2021-09-01")
#
# stats = qns.calc_stat(data, weights.sel(time=slice("2022-04-03", None)))
#
# **At 12 months:**
#
# data = qndata.stocks.load_ndx_data(min_date="2019-09-01")
#
# stats = qns.calc_stat(data, weights.sel(time=slice("2020-10-04", None)))

# %%
#DataFrame
mydf = pd.DataFrame(columns = ['slow(day)','fast(day)','Sharpe Ratio'])
mydf.name = "At 6 months"
mydf2 = pd.DataFrame(columns = ['slow(day)','fast(day)','Sharpe Ratio'])
mydf2.name = "At 24 months"

# %%
# At 6 months Period: 2021-09-01 - 2022-09-30
mydf.loc[len(mydf.index)] = [240,24,0.6133062226768218]
mydf.loc[len(mydf.index)] = [240,12,0.6141439931677769]
mydf.loc[len(mydf.index)] = [240,6,0.5949926630936527]
mydf.loc[len(mydf.index)] = [186,24,0.5238768129861856]
mydf.loc[len(mydf.index)] = [186,12,0.5470169694819819]
mydf.loc[len(mydf.index)] = [186,6,0.5171608552607099]
mydf.loc[len(mydf.index)] = [101,24,-0.31163859274517786]
mydf.loc[len(mydf.index)] = [101,12,-0.40535802773994056]
mydf.loc[len(mydf.index)] = [101,6,-0.3103930363251192]

# %%
mydf.sort_values(by=['Sharpe Ratio'], inplace=True, ascending=False)
mydf
# Out:
#    slow(day)  fast(day)  Sharpe Ratio
# 1      240.0       12.0      0.614144
# 0      240.0       24.0      0.613306
# 2      240.0        6.0      0.594993
# 4      186.0       12.0      0.547017
# 3      186.0       24.0      0.523877
# 5      186.0        6.0      0.517161
# 8      101.0        6.0     -0.310393
# 6      101.0       24.0     -0.311639
# 7      101.0       12.0     -0.405358

# %%
# At 24 months Period: 2019-09-03 - 2022-09-30
mydf2.loc[len(mydf2.index)] = [240,24,0.3997061964981932]
mydf2.loc[len(mydf2.index)] = [240,12,0.3166750770074988]
mydf2.loc[len(mydf2.index)] = [240,6,0.31798941873476966]
mydf2.loc[len(mydf2.index)] = [186,24,0.33872427742987365]
mydf2.loc[len(mydf2.index)] = [186,12,0.20035259916503056]
mydf2.loc[len(mydf2.index)] = [186,6,0.18045125928773784]
mydf2.loc[len(mydf2.index)] = [101,24,-0.05586462737213312]
mydf2.loc[len(mydf2.index)] = [101,12,-0.13644647776637656]
mydf2.loc[len(mydf2.index)] = [101,6,-0.1991132504863267]

# %%
mydf2.sort_values(by=['Sharpe Ratio'], inplace=True, ascending=False)
mydf2
# Out:
#    slow(day)  fast(day)  Sharpe Ratio
# 0      240.0       24.0      0.399706
# 3      186.0       24.0      0.338724
# 2      240.0        6.0      0.317989
# 1      240.0       12.0      0.316675
# 4      186.0       12.0      0.200353
# 5      186.0        6.0      0.180451
# 6      101.0       24.0     -0.055865
# 7      101.0       12.0     -0.136446
# 8      101.0        6.0     -0.199113

# %% [markdown]
# At 6 months
#
# The values obtained are shown below.

# %% [markdown]
# ***Slow = 240 Fast = 24***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 240 Fast = 12**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 240 Fast = 6**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 186 Fast = 24**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 186 Fast = 12**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 186 Fast = 6**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 101 Fast = 24**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 101 Fast = 12**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Slow = 101 Fast = 6**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
